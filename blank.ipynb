# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bui Quang Hai**

# %% [markdown]
# _I am interested in data science because I like it_

# %% [markdown]
# ### This is code

# %%
1+1
# Out:
# 2

# %% [markdown]
# ### This is duck
# 1. cute
# 2. yellow
# 3. multiple
# <img src="attachment:duck.jpg" width="500"/>
#
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
